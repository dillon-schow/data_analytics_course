# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("/Users/dillonschow/dpl_course/data_analytics_course/ExercisesByWeek/02-Graphing-n-Visualizations/02-pdf-report/pdf-report-py/sales-funnel.xlsx")
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
df['Status'] = df['Status'].astype('category')
df['Status'].cat.set_categories(['won', 'pending', 'declined', 'presented'], inplace=True)

# %%
df2 = pd.pivot_table(df, index=['Manager', 'Rep', 'Name'])

# %%
df2 = df2.reset_index()
df2.sort_values(['Manager', 'Rep', 'Price']).set_index(['Manager', 'Rep', 'Name'])
# Out:
#                                                           level_0  index  \
# Manager       Rep           Name
# Debra Henley  Craig Booker  Trantow-Barrows                     1      1
#                             Fritsch, Russel and Anderson        0      0
#               Daniel Hilton Kulas Inc                           3      3
#                             Kiehn-Spinka                        2      2
#               John Smith    Jerde-Hilpert                       5      5
#                             Barton LLC                          4      4
# Fred Anderson Cedric Moss   Stokes LLC                          8      8
#                             Purdy-Kunde                         7      7
#                             Herman LLC                          6      6
#               Wendy Yule    Kassulke, Ondricka and Metz         9      9
#                             Koepp Ltd                          11     11
# ...
